# %%
import os, sys

# Get the parent directory
parent_dir = os.path.abspath(os.path.join(os.getcwd(), '..'))

# Add the parent directory to sys.path
sys.path.insert(0, parent_dir)

from loaders import load_results
from plotters import plot_powervsvars, plot_powervscomp, plot_powervsnfeat

# %% [markdown]
# ### CG results

# %%
methods = ['uniform', 'rlss', 'rff']

results, config, vars = load_results("../results/susy_B200_niter400_mix0.05", methods=methods) 
print(config)
print(vars)
print(results.keys())
# Out:
# loading uniform
# ['../results/susy_B200_niter400_mix0.05/var24000/uniform/results.npy', '../results/susy_B200_niter400_mix0.05/var16000/uniform/results.npy', '../results/susy_B200_niter400_mix0.05/var40000/uniform/results.npy', '../results/susy_B200_niter400_mix0.05/var32000/uniform/results.npy', '../results/susy_B200_niter400_mix0.05/var8000/uniform/results.npy', '../results/susy_B200_niter400_mix0.05/var2000/uniform/results.npy', '../results/susy_B200_niter400_mix0.05/var4000/uniform/results.npy']
# loading rlss
# ['../results/susy_B200_niter400_mix0.05/var24000/rlss/results.npy', '../results/susy_B200_niter400_mix0.05/var16000/rlss/results.npy', '../results/susy_B200_niter400_mix0.05/var40000/rlss/results.npy', '../results/susy_B200_niter400_mix0.05/var32000/rlss/results.npy', '../results/susy_B200_niter400_mix0.05/var8000/rlss/results.npy', '../results/susy_B200_niter400_mix0.05/var2000/rlss/results.npy', '../results/susy_B200_niter400_mix0.05/var4000/rlss/results.npy']
# ...

# %%
plot_powervsvars(results, vars, config)

# %%
plot_powervscomp(results, 5, config)

# %%
plot_powervsnfeat(results, 5, config)
