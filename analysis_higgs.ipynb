# %%
from loaders import load_results
from plotters import plot_powervsvars, plot_powervscomp

# %%
methods = ['uniform', 'rlss', 'rff']

results, config, vars = load_results("results/2025-02-17/higgs_B200_niter400_mix0.2_reduced0", methods=methods) 
print(config)
print(vars)
print(results.keys())
# Out:
# loading uniform
# ['results/2025-02-17/higgs_B200_niter400_mix0.2_reduced0/var5000/uniform/results.npy', 'results/2025-02-17/higgs_B200_niter400_mix0.2_reduced0/var1000/uniform/results.npy', 'results/2025-02-17/higgs_B200_niter400_mix0.2_reduced0/var40000/uniform/results.npy', 'results/2025-02-17/higgs_B200_niter400_mix0.2_reduced0/var80000/uniform/results.npy', 'results/2025-02-17/higgs_B200_niter400_mix0.2_reduced0/var10000/uniform/results.npy', 'results/2025-02-17/higgs_B200_niter400_mix0.2_reduced0/var20000/uniform/results.npy', 'results/2025-02-17/higgs_B200_niter400_mix0.2_reduced0/var60000/uniform/results.npy']
# loading rlss
# ...

# %%
plot_powervsvars(results, vars, config)

# %%
plot_powervscomp(results, 5, config)
