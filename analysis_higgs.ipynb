# %%
from loaders import load_results
from utils import plot_powervsvars, plot_powervscomp

# %%
methods = ['uniform', 'rlss', 'rff']

results, config, vars = load_results("results/higgs_B200_niter400_mix0.2_reduced0", methods=methods) 
print(config)
print(vars)
print(results.keys())
# Out:
# loading uniform
# ['results/higgs_B200_niter400_mix0.2_reduced0/var5000/uniform/results.npy', 'results/higgs_B200_niter400_mix0.2_reduced0/var1000/uniform/results.npy', 'results/higgs_B200_niter400_mix0.2_reduced0/var40000/uniform/results.npy', 'results/higgs_B200_niter400_mix0.2_reduced0/var80000/uniform/results.npy', 'results/higgs_B200_niter400_mix0.2_reduced0/var10000/uniform/results.npy', 'results/higgs_B200_niter400_mix0.2_reduced0/var20000/uniform/results.npy', 'results/higgs_B200_niter400_mix0.2_reduced0/var60000/uniform/results.npy']
# loading rlss
# ...

# %%
plot_powervsvars(results, vars, config)

# %%
print(vars)
# Out:
# [1000.0, 5000.0, 10000.0, 20000.0, 40000.0, 60000.0, 80000.0]

# %%
plot_powervscomp(results, 5, config)
