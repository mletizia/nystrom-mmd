# %%
from loaders import load_results
from utils import plot_powervsvars, plot_powervscomp

# %% [markdown]
# ### CG results

# %%
methods = ['uniform', 'rlss', 'rff']

results, config, vars = load_results("results/2025-02-14/cg_ntot5000_B200_niter400", methods=methods) 
print(config)
print(vars)
print(results.keys())
# Out:
# loading uniform
# ['2025-02-14/cg_ntot5000_B200_niter400/var0.63/uniform/results.npy', '2025-02-14/cg_ntot5000_B200_niter400/var0.54/uniform/results.npy', '2025-02-14/cg_ntot5000_B200_niter400/var0.6/uniform/results.npy', '2025-02-14/cg_ntot5000_B200_niter400/var0.51/uniform/results.npy', '2025-02-14/cg_ntot5000_B200_niter400/var0.66/uniform/results.npy', '2025-02-14/cg_ntot5000_B200_niter400/var0.57/uniform/results.npy']
# loading rlss
# ['2025-02-14/cg_ntot5000_B200_niter400/var0.63/rlss/results.npy', '2025-02-14/cg_ntot5000_B200_niter400/var0.54/rlss/results.npy', '2025-02-14/cg_ntot5000_B200_niter400/var0.6/rlss/results.npy', '2025-02-14/cg_ntot5000_B200_niter400/var0.51/rlss/results.npy', '2025-02-14/cg_ntot5000_B200_niter400/var0.66/rlss/results.npy', '2025-02-14/cg_ntot5000_B200_niter400/var0.57/rlss/results.npy']
# loading rff
# ['2025-02-14/cg_ntot5000_B200_niter400/var0.63/rff/results.npy', '2025-02-14/cg_ntot5000_B200_niter400/var0.54/rff/results.npy', '2025-02-14/cg_ntot5000_B200_niter400/var0.6/rff/results.npy', '2025-02-14/cg_ntot5000_B200_niter400/var0.51/rff/results.npy', '2025-02-14/cg_ntot5000_B200_niter400/var0.66/rff/results.npy', '2025-02-14/cg_ntot5000_B200_niter400/var0.57/rff/results.npy']
# {'dataset': 'cg', 'ntot': 5000, 'B': 200, 'niter': 400}
# [0.51, 0.54, 0.57, 0.6, 0.63, 0.66]
# dict_keys(['uniform', 'rlss', 'rff'])

# %%
plot_powervsvars(results, vars, config)

# %%
print(vars)
# Out:
# [0.51, 0.54, 0.57, 0.6, 0.63, 0.66]

# %%
plot_powervscomp(results, 4, config)
